# %%
from pybaseball import bwar_bat

# get war stats from baseball reference 
data = bwar_bat(return_all=True)
data.columns
# Out:
# Index(['name_common', 'age', 'mlb_ID', 'player_ID', 'year_ID', 'team_ID',
#        'stint_ID', 'lg_ID', 'PA', 'G', 'Inn', 'runs_bat', 'runs_br', 'runs_dp',
#        'runs_field', 'runs_infield', 'runs_outfield', 'runs_catcher',
#        'runs_good_plays', 'runs_defense', 'runs_position', 'runs_position_p',
#        'runs_replacement', 'runs_above_rep', 'runs_above_avg',
#        'runs_above_avg_off', 'runs_above_avg_def', 'WAA', 'WAA_off', 'WAA_def',
#        'WAR', 'WAR_def', 'WAR_off', 'WAR_rep', 'salary', 'pitcher', 'teamRpG',
#        'oppRpG', 'oppRpPA_rep', 'oppRpG_rep', 'pyth_exponent',
#        'pyth_exponent_rep', 'waa_win_perc', 'waa_win_perc_off',
#        'waa_win_perc_def', 'waa_win_perc_rep', 'OPS_plus', 'TOB_lg', 'TB_lg'],
#       dtype='object')

# %%
barry_bonds_data = data[data['name_common'] == 'Barry Bonds']
# Filter the columns from barry_bonds_data
barry_bonds_war = barry_bonds_data[
    ['name_common', 'age', 'mlb_ID', 'player_ID', 'year_ID', 'team_ID', 'lg_ID', 
     'PA', 'G', 'WAR', 'WAR_def', 'WAR_off', 'WAR_rep']
]

# Display the modified table
barry_bonds_war
# Out:
#        name_common   age    mlb_ID  player_ID  year_ID team_ID lg_ID     PA  \
# 10104  Barry Bonds  21.0  111188.0  bondsba01     1986     PIT    NL  484.0
# 10105  Barry Bonds  22.0  111188.0  bondsba01     1987     PIT    NL  611.0
# 10106  Barry Bonds  23.0  111188.0  bondsba01     1988     PIT    NL  614.0
# 10107  Barry Bonds  24.0  111188.0  bondsba01     1989     PIT    NL  679.0
# 10108  Barry Bonds  25.0  111188.0  bondsba01     1990     PIT    NL  621.0
# 10109  Barry Bonds  26.0  111188.0  bondsba01     1991     PIT    NL  634.0
# 10110  Barry Bonds  27.0  111188.0  bondsba01     1992     PIT    NL  612.0
# 10111  Barry Bonds  28.0  111188.0  bondsba01     1993     SFG    NL  674.0
# 10112  Barry Bonds  29.0  111188.0  bondsba01     1994     SFG    NL  474.0
# 10113  Barry Bonds  30.0  111188.0  bondsba01     1995     SFG    NL  635.0
# 10114  Barry Bonds  31.0  111188.0  bondsba01     1996     SFG    NL  675.0
# 10115  Barry Bonds  32.0  111188.0  bondsba01     1997     SFG    NL  690.0
# 10116  Barry Bonds  33.0  111188.0  bondsba01     1998     SFG    NL  697.0
# 10117  Barry Bonds  34.0  111188.0  bondsba01     1999     SFG    NL  434.0
# 10118  Barry Bonds  35.0  111188.0  bondsba01     2000     SFG    NL  607.0
# 10119  Barry Bonds  36.0  111188.0  bondsba01     2001     SFG    NL  664.0
# 10120  Barry Bonds  37.0  111188.0  bondsba01     2002     SFG    NL  612.0
# 10121  Barry Bonds  38.0  111188.0  bondsba01     2003     SFG    NL  550.0
# 10122  Barry Bonds  39.0  111188.0  bondsba01     2004     SFG    NL  617.0
# 10123  Barry Bonds  40.0  111188.0  bondsba01     2005     SFG    NL   52.0
# 10124  Barry Bonds  41.0  111188.0  bondsba01     2006     SFG    NL  493.0
# 10125  Barry Bonds  42.0  111188.0  bondsba01     2007     SFG    NL  477.0
#
#          G    WAR  WAR_def  WAR_off  WAR_rep
# 10104  113   3.54     1.02     2.58     1.67
# 10105  150   5.79     2.12     3.24     2.09
# 10106  144   6.25     0.37     5.25     2.13
# 10107  159   7.99     3.60     3.71     2.18
# 10108  151   9.74     2.54     6.49     1.95
# 10109  153   7.97     1.48     5.82     2.05
# 10110  140   9.03     0.03     8.31     1.78
# 10111  159   9.92     0.43     8.76     2.02
# 10112  112   6.24     0.07     5.70     1.46
# 10113  144   7.52     0.69     6.20     1.87
# 10114  158   9.65     0.26     8.87     2.07
# 10115  159   8.17     0.71     6.85     2.03
# 10116  156   8.09     0.30     7.19     2.05
# 10117  102   3.82    -0.81     4.23     1.32
# 10118  143   7.72    -0.05     7.30     1.82
# 10119  153  11.85    -1.16    12.40     1.98
# 10120  143  11.75    -0.61    11.76     1.87
# 10121  130   9.17    -0.08     8.68     1.68
# 10122  147  10.64    -1.47    11.49     1.88
# 10123   14   0.58     0.05     0.48     0.16
# 10124  130   4.01    -0.39     3.91     1.47
# 10125  126   3.36    -1.49     4.38     1.41

# %%
from pybaseball import bwar_pitch

data = bwar_pitch()
# Out:
#        name_common    mlb_ID  player_ID  year_ID team_ID  stint_ID lg_ID   G  \
# 0   George Bechtel  110756.0  bechtge01     1871     ATH         1   NaN   3
# 1     Asa Brainard  111373.0  brainas01     1871     OLY         1   NaN  30
# 2     Bob Ferguson  114069.0  fergubo01     1871     NYU         1   NaN   1
# 3  Cherokee Fisher  114181.0  fishech01     1871     ROK         1   NaN  24
# 4      Frank Fleet  114224.0  fleetfr01     1871     NYU         1   NaN   1
#
#    GS   RA      xRA     BIP  BIP_perc  salary   ERA_plus  WAR_rep     WAA  \
# 0   3   42   29.183   134.0    0.1176     NaN  52.682609   0.2455 -0.5925
# 1  30  292  310.377  1237.0    0.9486     NaN  93.906818   2.4889 -0.1260
# 2   0    9    1.185    14.0    0.0104     NaN  19.733333   0.0102 -0.3177
# 3  24  257  250.929  1031.0    0.9398     NaN  97.129126   2.0067  0.2520
# 4   1   21   10.665    54.0    0.0400     NaN  39.680000   0.0847 -0.3861
#
#    WAA_adj   WAR
# 0  -0.0156 -0.36
# 1  -0.1582  2.20
# 2  -0.0006 -0.31
# 3  -0.1276  2.13
# 4  -0.0054 -0.31

# %%
pedro_martinez_data = data[data['name_common'] == 'Pedro Martinez']
pedro_martinez_war = pedro_martinez_data[
    ['name_common', 'mlb_ID', 'player_ID', 'year_ID', 'team_ID', 'lg_ID', 
     'G', 'GS', 'WAR']
]

pedro_martinez_war
# Out:
#           name_common    mlb_ID  player_ID  year_ID team_ID lg_ID   G  GS  \
# 32149  Pedro Martinez  118377.0  martipe02     1992     LAD    NL   2   1
# 32676  Pedro Martinez  118377.0  martipe02     1993     LAD    NL  65   2
# 33177  Pedro Martinez  118377.0  martipe02     1994     MON    NL  24  23
# 33756  Pedro Martinez  118377.0  martipe02     1995     MON    NL  30  30
# 34371  Pedro Martinez  118377.0  martipe02     1996     MON    NL  33  33
# 34962  Pedro Martinez  118377.0  martipe02     1997     MON    NL  31  31
# 35241  Pedro Martinez  118377.0  martipe02     1998     BOS    AL  33  33
# 35872  Pedro Martinez  118377.0  martipe02     1999     BOS    AL  31  29
# 36513  Pedro Martinez  118377.0  martipe02     2000     BOS    AL  29  29
# 37186  Pedro Martinez  118377.0  martipe02     2001     BOS    AL  18  18
# 37851  Pedro Martinez  118377.0  martipe02     2002     BOS    AL  30  30
# 38516  Pedro Martinez  118377.0  martipe02     2003     BOS    AL  29  29
# 39214  Pedro Martinez  118377.0  martipe02     2004     BOS    AL  33  33
# 40202  Pedro Martinez  118377.0  martipe02     2005     NYM    NL  31  31
# 40882  Pedro Martinez  118377.0  martipe02     2006     NYM    NL  23  23
# 41593  Pedro Martinez  118377.0  martipe02     2007     NYM    NL   5   5
# 42302  Pedro Martinez  118377.0  martipe02     2008     NYM    NL  20  20
# 43025  Pedro Martinez  118377.0  martipe02     2009     PHI    NL   9   9
#
#          WAR
# 32149   0.30
# 32676   3.00
# 33177   2.42
# 33756   4.73
# 34371   4.02
# 34962   8.99
# 35241   7.26
# 35872   9.78
# 36513  11.71
# 37186   5.08
# 37851   6.48
# 38516   8.02
# 39214   5.46
# 40202   6.95
# 40882   0.96
# 41593   0.58
# 42302  -0.39
# 43025   0.73

# %%
import matplotlib.pyplot as plt
import numpy as np 
from pybaseball import bwar_bat, bwar_pitch

bat_data = bwar_bat()
pitch_data = bwar_pitch()

# %%
import numpy as np
import matplotlib.pyplot as plt
from pybaseball import bwar_bat
from team_colors import team_color_map  # Ensure your team_colors.py is in the same directory

def plot_batter_war(player_name):
    # Get WAR stats from Baseball Reference
    data = bwar_bat(return_all=True)

    # Filter data for the given player
    player_data = data[data['name_common'] == player_name]

    # Sort the data by year to ensure it's in chronological order
    player_data = player_data.sort_values(by='year_ID')

    # Extract the relevant data for plotting
    years = player_data['year_ID'].to_numpy()
    war_totals = player_data['WAR'].to_numpy()
    team_ids = player_data['team_ID'].to_numpy()

    # Plot the WAR totals for each season
    plt.figure(figsize=(10, 6))

    # Track peak WAR and corresponding year
    peak_year_index = np.argmax(war_totals)
    peak_year = years[peak_year_index]
    peak_war = war_totals[peak_year_index]

    # Plot dots and lines
    for i in range(len(years)):
        color = team_color_map.get(team_ids[i], "#000000")  # Default to black if team ID is not found
        plt.plot(years[i], war_totals[i], marker='o', linestyle='-', color=color)
        
        # Add WAR number labels directly above the dot, slightly higher for better visibility
        plt.text(years[i], war_totals[i] + 0.3, f'{war_totals[i]:.1f}', fontsize=9, ha='center')

        # Add subtle lines between each dot (except the last one)
        if i < len(years) - 1:
            plt.plot(years[i:i+2], war_totals[i:i+2], linestyle='--', color=color, alpha=0.3)  # Set alpha to 0.3 for faint lines

    # Highlight the peak year with a circle
    plt.scatter(peak_year, peak_war, color='gold', s=100, edgecolor='black', label='PEAK', zorder=5)

    # Add titles and labels
    plt.title(f"{player_name}'s WAR by Season", fontsize=14)
    plt.xlabel('Year', fontsize=12)
    plt.ylabel('bWAR', fontsize=12)

    # Add a legend with lines representing performance categories
    plt.axhline(y=8, color='purple', linestyle='-', label='8+ MVP', alpha=0.3)  # Set alpha for faintness
    plt.axhline(y=5, color='blue', linestyle='-', label='5+ All-Star', alpha=0.3)
    plt.axhline(y=2, color='green', linestyle='-', label='2+ Starter', alpha=0.3)
    plt.axhline(y=0, color='orange', linestyle='-', label='0-2 Bench', alpha=0.3)
    plt.axhline(y=-0.1, color='red', linestyle='-', label='< 0 Below Replacement', alpha=0.3)

    # Set y-ticks explicitly to increments of 2
    max_war = int(np.ceil(max(war_totals)))  # Get the maximum WAR value and round up
    plt.yticks(np.arange(0, max_war + 2, 2))  # Create ticks from 0 to max_war with step of 2

    # Position the legend outside the plot to the right
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=8, frameon=False)

    # Show grid and the plot
    plt.grid(True)
    plt.xticks(np.arange(min(years), max(years) + 1, 1), rotation=45)
    plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust layout to make room for the legend
    
    # Display the plot
    plt.show()

# Example usage
plot_batter_war('Barry Bonds')  # Correct way to call the function

# %%
def plot_pitcher_war(player_name):
    # Get WAR stats from Baseball Reference
    data = bwar_pitch(reimport numpy as np
import matplotlib.pyplot as plt
from pybaseball import bwar_bat
from team_colors import team_color_map  # Ensure your team_colors.py is in the same directory

def plot_batter_war(player_name):
    # Get WAR stats from Baseball Reference
    data = bwar_bat(return_all=True)

    # Filter data for the given player
    player_data = data[data['name_common'] == player_name]

    # Sort the data by year to ensure it's in chronological order
    player_data = player_data.sort_values(by='year_ID')

    # Extract the relevant data for plotting
    years = player_data['year_ID'].to_numpy()
    war_totals = player_data['WAR'].to_numpy()
    team_ids = player_data['team_ID'].to_numpy()

    # Plot the WAR totals for each season
    plt.figure(figsize=(10, 6))

    # Track peak WAR and corresponding year
    peak_year_index = np.argmax(war_totals)
    peak_year = years[peak_year_index]
    peak_war = war_totals[peak_year_index]

    # Plot dots and lines
    for i in range(len(years)):
        color = team_color_map.get(team_ids[i], "#000000")  # Default to black if team ID is not found
        plt.plot(years[i], war_totals[i], marker='o', linestyle='-', color=color)
        
        # Add WAR number labels directly above the dot, slightly higher for better visibility
        plt.text(years[i], war_totals[i] + 0.3, f'{war_totals[i]:.1f}', fontsize=9, ha='center')

        # Add subtle lines between each dot (except the last one)
        if i < len(years) - 1:
            plt.plot(years[i:i+2], war_totals[i:i+2], linestyle='--', color=color, alpha=0.3)  # Set alpha to 0.3 for faint lines

    # Highlight the peak year with a circle
    plt.scatter(peak_year, peak_war, color='gold', s=100, edgecolor='black', label='PEAK', zorder=5)

    # Add titles and labels
    plt.title(f"{player_name}'s WAR by Season", fontsize=14)
    plt.xlabel('Year', fontsize=12)
    plt.ylabel('bWAR', fontsize=12)

    # Add a legend with lines representing performance categories
    plt.axhline(y=8, color='purple', linestyle='-', label='8+ MVP', alpha=0.3)  # Set alpha for faintness
    plt.axhline(y=5, color='blue', linestyle='-', label='5+ All-Star', alpha=0.3)
    plt.axhline(y=2, color='green', linestyle='-', label='2+ Starter', alpha=0.3)
    plt.axhline(y=0, color='orange', linestyle='-', label='0-2 Bench', alpha=0.3)
    plt.axhline(y=-0.1, color='red', linestyle='-', label='< 0 Below Replacement', alpha=0.3)

    # Set y-ticks explicitly to increments of 2
    max_war = int(np.ceil(max(war_totals)))  # Get the maximum WAR value and round up
    plt.yticks(np.arange(0, max_war + 2, 2))  # Create ticks from 0 to max_war with step of 2

    # Position the legend outside the plot to the right
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=8, frameon=False)

    # Show grid and the plot
    plt.grid(True)
    plt.xticks(np.arange(min(years), max(years) + 1, 1), rotation=45)
    plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust layout to make room for the legend
    
    # Display the plot
    plt.show()

# Example usage
plot_batter_war('Barry Bonds')  # Correct way to call the function
turn_all=True)

    # Filter data for the given player
    player_data = data[data['name_common'] == player_name]

    # Sort the data by year to ensure it's in chronological order
    player_data = player_data.sort_values(by='year_ID')

    # Extract the relevant data for plotting
    years = player_data['year_ID'].to_numpy()
    war_totals = player_data['WAR'].to_numpy()
    team_ids = player_data['team_ID'].to_numpy()

    # Plot the WAR totals for each season
    plt.figure(figsize=(10, 6))

    # Track peak WAR and corresponding year
    peak_year_index = np.argmax(war_totals)
    peak_year = years[peak_year_index]
    peak_war = war_totals[peak_year_index]

    # Plot dots and lines
    for i in range(len(years)):
        color = team_color_map.get(team_ids[i], "#000000")  # Default to black if team ID is not found
        plt.plot(years[i], war_totals[i], marker='o', linestyle='-', color=color)
        
        # Add WAR number labels directly above the dot, slightly higher for better visibility
        plt.text(years[i], war_totals[i] + 0.2, f'{war_totals[i]:.1f}', fontsize=9, ha='center')

        # Add subtle lines between each dot (except the last one)
        if i < len(years) - 1:
            plt.plot(years[i:i+2], war_totals[i:i+2], linestyle='--', color=color, alpha=0.3)  # Set alpha to 0.3 for faint lines

    # Highlight the peak year with a circle
    plt.scatter(peak_year, peak_war, color='gold', s=100, edgecolor='black', label='PEAK', zorder=5)

    # Add titles and labels
    plt.title(f"{player_name}'s WAR by Season", fontsize=14)
    plt.xlabel('Year', fontsize=12)
    plt.ylabel('WAR', fontsize=12)

    # Add a legend with lines representing performance categories
    plt.axhline(y=8, color='purple', linestyle='-', label='8+ MVP', alpha=0.3)  # Set alpha for faintness
    plt.axhline(y=5, color='blue', linestyle='-', label='5+ All-Star', alpha=0.3)
    plt.axhline(y=2, color='green', linestyle='-', label='2+ Starter', alpha=0.3)
    plt.axhline(y=0, color='orange', linestyle='-', label='0-2 Bench', alpha=0.3)
    plt.axhline(y=-0.1, color='red', linestyle='-', label='< 0 Minor Lg', alpha=0.3)

    # Position the legend outside the plot to the right
    plt.legend(loc='upper left', bbox_to_anchor=(1, 1), fontsize=8, frameon=False)

    # Show grid and the plot
    plt.grid(True)
    plt.xticks(np.arange(min(years), max(years) + 1, 1), rotation=45)
    plt.tight_layout(rect=[0, 0, 0.85, 1])  # Adjust layout to make room for the legend
    
    # Display the plot
    plt.show()

# Example usage
plot_pitcher_war('Roger Clemens')  # Correct way to call the function
